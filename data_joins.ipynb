# %%
import pandas as pd
import os

# %%
main_df = pd.read_csv("cleaned_files/alunos_por_escolaridade_clean.csv")
df_2 = pd.read_csv("cleaned_files/alunos_ensino_superior_clean.csv")
df_3 = pd.read_csv("cleaned_files/alunos_ensino_secundario_por_oferta.csv")
df_4 = pd.read_csv("cleaned_files/proporcao_CT_ensino_superior.csv")
df_5 = pd.read_csv("cleaned_files/students_per_computer.csv")
df_6 = pd.read_csv("cleaned_files/students_per_psychologist.csv")

# %%
#joined_1 = main_df.join(df_2, on=["year", "region"], how="inner")
main = pd.merge(main_df, df_2, left_on=["year", "region"], right_on=["year", "region"], how="left")

# %%
main = pd.merge(main, df_3, left_on=["year", "region"], right_on=["year", "region"], how="left")

# %%
main = pd.merge(main, df_4, left_on=["year", "region"], right_on=["year", "region"], how="left")

# %%
main = pd.merge(main, df_5, left_on=["year", "region"], right_on=["year", "region"], how="left")

# %%
main = pd.merge(main, df_6, left_on=["year", "region"], right_on=["year", "region"], how="left")

# %%
main.head()
# Out:
#           year             region  kindergarten_public  kindergarten_private  \
# 0  2020 / 2021           Portugal             135372.0              115688.0
# 1  2020 / 2021         Continente             128029.0              110589.0
# 2  2020 / 2021              Norte              47662.0               34890.0
# 3  2020 / 2021         Alto Minho               3408.0                1612.0
# 4  2020 / 2021  Arcos de Valdevez                188.0                 179.0
#
#    1-4_gr_public  1_4_gr_private  5_6_gr_public  5_6_gr_private  \
# 0       322736.0         50373.0       185020.0         25044.0
# 1       306605.0         47173.0       175285.0         24232.0
# 2       105095.0         13873.0        61718.0          7550.0
# 3         6684.0           273.0         3859.0           168.0
# 4          529.0             NaN          270.0             2.0
#
#    7_9_gr_public  7_9_gr_private  ...  10_12_private_professional_CP  \
# ...

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23676 entries, 0 to 23675
# Data columns (total 38 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   year                                      23676 non-null  object
#  1   region                                    23676 non-null  object
#  2   kindergarten_public                       19018 non-null  float64
#  3   kindergarten_private                      18383 non-null  float64
#  4   1-4_gr_public                             19033 non-null  float64
#  5   1_4_gr_private                            14738 non-null  float64
#  6   5_6_gr_public                             19003 non-null  float64
#  7   5_6_gr_private                            14613 non-null  float64
#  8   7_9_gr_public                             18996 non-null  float64
#  9   7_9_gr_private                            15376 non-null  float64
# ...

# %%
main.to_csv("main.csv")
